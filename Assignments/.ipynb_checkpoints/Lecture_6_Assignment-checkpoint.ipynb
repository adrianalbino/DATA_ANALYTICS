# %% [markdown]
# Instructions:
#
# 1. Choose a unique dataset from: https://archive.ics.uci.edu
# 2. Your dataset should be unique from your classmates otherwise no points will be given for this exercise.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('dataset.csv')
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
df = data

median_price = df['Y house price of unit area'].median()
df['target_label'] = (df['Y house price of unit area'] > median_price).astype(int)

correlation_with_label = df.corr()['target_label'].abs().sort_values(ascending=False)

correlation_with_label = correlation_with_label.drop('target_label')

top_correlated_features = correlation_with_label.head(5)

print(top_correlated_features)
# Out:
# Y house price of unit area                0.787519
# X3 distance to the nearest MRT station    0.549349
# X4 number of convenience stores           0.537772
# X5 latitude                               0.451833
# X6 longitude                              0.419601
# Name: target_label, dtype: float64

# %% [markdown]
# Our approach here will be one of using Cross Validation on 90% of the dataset, and then judging our results on a final test set of 10% to evaluate our model.
#
# **TASK: Split the data into features and labels, and then split into a training set and test set, with 90% for Cross-Validation training, and 10% for a final test set.**

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# Splitting
X = df.drop(['Y house price of unit area', 'target_label'], axis=1)
y = df['target_label']


X_train_cv, X_test, y_train_cv, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# **TASK: Create a PipeLine that contains both a StandardScaler and a KNN model**

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

# %% [markdown]
# **TASK: Perform a grid-search with the pipeline to test various values of k and report back the best performing parameters.**

# %%
param_grid = {
    'knn__n_neighbors': [3, 5, 7, 9, 11]
}


grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train_cv, y_train_cv)


print("Best performing parameters:")
print(grid_search.best_params_)
# Out:
# Best performing parameters:
# {'knn__n_neighbors': 11}

# %%
**(HARD) TASK: Using the .cv_results_ dictionary, see if you can create a plot of the mean test scores per K value.**

# %%
mean_test_scores = grid_search.cv_results_['mean_test_score']
k_values = param_grid['knn__n_neighbors']

plt.figure(figsize=(10, 6))
plt.plot(k_values, mean_test_scores, marker='o')
plt.title('Mean Test Scores per K value')
plt.xlabel('K value')
plt.ylabel('Mean Test Score')
plt.grid(True)
plt.show()

# %% [markdown]
# **(HARD) TASK: Using the .cv_results_ dictionary, see if you can create a plot of the mean test scores per K value.**

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = grid_search.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89        22
#            1       0.89      0.85      0.87        20
#
#     accuracy                           0.88        42
#    macro avg       0.88      0.88      0.88        42
# weighted avg       0.88      0.88      0.88        42
#
# Confusion Matrix:
# [[20  2]
#  [ 3 17]]
