# %% [markdown]
# $\textbf{PROGRAMMING ASSIGNMENT}$
# ---
#
# Data: https://archive.ics.uci.edu
#
# Instructions: Choose a dataset of your liking and perform the following:
#
# 1. Create a Correlation Plot
#
# 2. Check the distribution of each column and determine which probability distiribution it fits.
#
# 3. Create a summary statistics.
#
# 4. Perform a hypothesis test (Code from scratch).

# %%
import pandas as pd
data = pd.read_csv('dataset.csv')
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
import plotly.express as px
# Correlation
df = data
df_corr = df.corr().round(1)  
# Mask to matrix
mask = np.zeros_like(df_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
# Viz
df_corr_viz = df_corr.mask(mask).dropna(how='all')
fig = px.imshow(df_corr_viz, text_auto=True)
fig.update_layout(height = 900, width=900)
fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure()
for i in df.columns:
    fig.add_trace(go.Box(y=df[str(i)], name=str(i)))
fig.update_layout(showlegend=False,height = 700, width=800)
fig.show()

# %%
standard = (df-df.mean())/df.std()

fig = go.Figure()
for i in standard.columns:
    fig.add_trace(go.Box(y=standard[str(i)], name=str(i)))
fig.update_layout(showlegend=False,height = 700, width=800)
fig.show()

# %%
import plotly.express as px
# Correlation
std_corr = standard.corr().round(1)  
# Mask to matrix
mask = np.zeros_like(std_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
# Viz
df_corr_viz = df_corr.mask(mask).dropna(how='all')
fig = px.imshow(df_corr_viz, text_auto=True)
fig.update_layout(height = 900, width=900)
fig.show()

# %%
import plotly.express as px

# Loop through each column in the DataFrame
for column in df.columns:
    fig = px.histogram(df, x=column, nbins=50, title=f'Histogram of {column}')
    fig.show()

# %%
# Loop through each column in the DataFrame for density plots
for column in df.columns:
    fig = px.histogram(df, x=column, nbins=50, marginal='violin', histnorm='probability density', title=f'Density Plot of {column}')
    fig.show()

# %%
from scipy.stats import shapiro, normaltest

# Check for normality
normality_results = {}
for column in df.columns:
    stat, p_value = shapiro(df[column].dropna())  # Shapiro-Wilk test
    normality_results[column] = {'Shapiro-Wilk Test Statistic': stat, 'p-value': p_value}

print(normality_results)
# Out:
# {'No': {'Shapiro-Wilk Test Statistic': 0.9546941518783569, 'p-value': 5.729228758077909e-10}, 'X1 transaction date': {'Shapiro-Wilk Test Statistic': 0.9349325299263, 'p-value': 1.82187685077162e-12}, 'X2 house age': {'Shapiro-Wilk Test Statistic': 0.9467391967773438, 'p-value': 4.798460587207565e-11}, 'X3 distance to the nearest MRT station': {'Shapiro-Wilk Test Statistic': 0.7381013631820679, 'p-value': 4.855018310165232e-25}, 'X4 number of convenience stores': {'Shapiro-Wilk Test Statistic': 0.9373714327812195, 'p-value': 3.4598203208641154e-12}, 'X5 latitude': {'Shapiro-Wilk Test Statistic': 0.9732913374900818, 'p-value': 6.887880772410426e-07}, 'X6 longitude': {'Shapiro-Wilk Test Statistic': 0.8708142042160034, 'p-value': 4.547814605988476e-18}, 'Y house price of unit area': {'Shapiro-Wilk Test Statistic': 0.9727507829666138, 'p-value': 5.413612598204054e-07}}

# %%
from scipy.stats import norm, lognorm, expon
import matplotlib.pyplot as plt

# Fit and compare different distributions
for column in df.columns:
    data = df[column].dropna()
    plt.figure(figsize=(10, 6))
    plt.hist(data, bins=30, density=True, alpha=0.6, color='b')

    # Normal distribution
    mu, std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2, label="Fit results: mu = %.2f,  std = %.2f" % (mu, std))

    plt.title(f'Distribution fitting for {column}')
    plt.legend()
    plt.show()

# %%
from scipy.stats import norm, lognorm, expon
import matplotlib.pyplot as plt

# Fit and compare different distributions
for column in df.columns:
    data = df[column].dropna()
    plt.figure(figsize=(10, 6))
    plt.hist(data, bins=30, density=True, alpha=0.6, color='b')

    # Normal distribution
    mu, std = norm.fit(data)
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2, label="Fit results: mu = %.2f,  std = %.2f" % (mu, std))

    plt.title(f'Distribution fitting for {column}')
    plt.legend()
    plt.show()

# %% [markdown]
# SUMMARY STATISTICS:

# %%
data = pd.read_csv('dataset.csv')

summary_statistics = data.describe()

# Include additional statistics like variance and skewness
summary_statistics.loc['variance'] = data.var()
summary_statistics.loc['skewness'] = data.skew()

# Print the summary statistics
summary_statistics
# Out:
#                     No  X1 transaction date  X2 house age  \
# count       414.000000           414.000000    414.000000
# mean        207.500000          2013.148971     17.712560
# std         119.655756             0.281967     11.392485
# min           1.000000          2012.667000      0.000000
# 25%         104.250000          2012.917000      9.025000
# 50%         207.500000          2013.167000     16.100000
# 75%         310.750000          2013.417000     28.150000
# max         414.000000          2013.583000     43.800000
# variance  14317.500000             0.079506    129.788704
# skewness      0.000000            -0.150572      0.382926
#
#           X3 distance to the nearest MRT station  \
# count                               4.140000e+02
# mean                                1.083886e+03
# std                                 1.262110e+03
# min                                 2.338284e+01
# 25%                                 2.893248e+02
# ...

# %% [markdown]
# Pearson Correlation Test:
#
# Null Hypothesis (H0): There is no correlation between the number of convenience stores nearby and house prices.
#
# Alternative Hypothesis (H1): There is a correlation between the distance to the number of convenience stores nearby and house prices.

# %%
# Extract data from the DataFrame
distance_to_mrt = df['X4 number of convenience stores'].tolist()
house_prices = df['Y house price of unit area'].tolist()

# Calculate the mean of each list
mean_distance = sum(distance_to_mrt) / len(distance_to_mrt)
mean_price = sum(house_prices) / len(house_prices)


# Calculate deviations and covariance
covariance = sum((mrt - mean_distance) * (price - mean_price) for mrt, price in zip(distance_to_mrt, house_prices))
covariance /= (len(distance_to_mrt) - 1)

# Calculate standard deviations
std_distance = (sum((mrt - mean_distance) ** 2 for mrt in distance_to_mrt) / (len(distance_to_mrt) - 1)) ** 0.5
std_price = (sum((price - mean_price) ** 2 for price in house_prices) / (len(house_prices) - 1)) ** 0.5

# Calculate Pearson correlation coefficient
correlation_coefficient = covariance / (std_distance * std_price)

print("Pearson Correlation Coefficient:", correlation_coefficient)
# Out:
# Pearson Correlation Coefficient: 0.5710049111111485

# %% [markdown]
# Interpretation:
#
# A Pearson Correlation Coefficient of 0.57 shows that there is a moderate or slight positive correlation between the number of convenience stores nearby and the house price of unit area. This means we can possibly reject the null hypothesis.
